# %%
# !pip install autotrain-advanced
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Out:
# INFO     | 2024-11-08 12:23:36 | autotrain.trainers.generic.utils:create_dataset_repo:23 - Creating dataset repo...
# INFO     | 2024-11-08 12:23:36 | autotrain.trainers.generic.utils:create_dataset_repo:31 - Uploading dataset...
# INFO     | 2024-11-08 12:23:37 | autotrain.trainers.generic.utils:create_dataset_repo:37 - Dataset uploaded.
# INFO     | 2024-11-08 12:23:41 | autotrain.cli.run_spacerunner:run:143 - Job ID: Vampyrian/autotrain-myspacerunner
# zsh:1: command not found: push_to_hub
